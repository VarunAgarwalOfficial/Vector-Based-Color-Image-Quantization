# %%
images = ["lenna" , "airplane" , "mandril" , "pepper" , "sailboat" , "yacht"]
methods = ["VB-CIQ" , "FASTOCTREE" , "K-MEANS" , "MAXIMUM" , "MEDIAN CUT"]

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
fig, ax = plt.subplots(nrows=6, ncols=5 , figsize=(200,200) )
for image in images:
    for i,col in enumerate(ax):
        im = Image.open(f"{methods[i]}/results/{image}/k8/reconstructed.png")
        col.imshow(im)

    fig.savefig(f"{image}ROW.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1072/3840336205.py in <module>
#       3     for i,col in enumerate(ax):
#       4         im = Image.open(f"{methods[i]}/results/{image}/k8/reconstructed.png")
# ----> 5         col.imshow(im)
#       6
#       7     fig.savefig(f"{image}ROW.png")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'imshow'
